# %%
import cv2
import matplotlib.pyplot as plt

# %%
image=cv2.imread(r"headphone.jpg")
RGB=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
image.shape
# Out:
# (183, 275, 3)

# %%
cv2.imshow("HEADPHONE",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image.shape
RGB=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(RGB)
plt.grid(True)
plt.xticks(range(0, image.shape[1], 15))  # x axis ticks every 50 pixels
plt.yticks(range(0, image.shape[0], 15))  # y axis ticks every 50 pixels
plt.show()

# %%
cropped= image[80:135,110:155]

# %%
plt.imshow(cropped)

# %%
cropped.shape
# Out:
# (55, 45, 3)

# %%
Resize=cv2.resize(cropped,(224,224))

# %%
cv2.imshow("Cropped",Resize)
cv2.waitKey(0)
cv2.destroyAllWindows()
